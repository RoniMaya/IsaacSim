# %%
# Copyright (c) 2020-2023, NVIDIA CORPORATION. All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto. Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.
#Ptry:

"""
This is a minimal, self-contained script to demonstrate how to retrieve 
LiDAR point cloud data in a headless Isaac Sim simulation.

Execution:
    - Make sure your Isaac Sim python environment is sourced.
    - Run from the terminal: ./python.sh <path_to_this_script>
"""



# Import the main simulation application class
from isaacsim import SimulationApp
# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this

# Define the configuration for the headless simulation
# This dictionary is passed to the SimulationApp constructor
HEADLESS_CONFIG = {"headless": True, "renderer": "RayTracedLighting", "active_gpu": 0}

# Start the simulation application# Copyright (c) 2020-2023, NVIDIA CORPORATION. All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto. Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.
#P

"""
This is a minimal, self-contained script to demonstrate how to retrieve 
LiDAR point cloud data in a headless Isaac Sim simulation.

Execution:
    - Make sure your Isaac Sim python environment is sourced.
    - Run from the terminal: ./python.sh <path_to_this_script>
"""



# Import the main simulation application class
from isaacsim import SimulationApp
# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this

# Define the configuration for the headless simulation
# This dictionary is passed to the SimulationApp constructor
HEADLESS_CONFIG = {"headless": True, "renderer": "RayTracedLighting", "active_gpu": 0}

# Start the simulation application
# We use a context manager to ensure the application is properly cleaned up
simulation_app = SimulationApp(HEADLESS_CONFIG)
# Out:
# Starting kit application with the following args:  ['/home/ronim/isaacsim/_build/linux-x86_64/release/exts/isaacsim.simulation_app/isaacsim/simulation_app/simulation_app.py', '/home/ronim/isaacsim/_build/linux-x86_64/release/apps/isaacsim.exp.base.python.kit', '--/app/tokens/exe-path=/home/ronim/isaacsim/_build/linux-x86_64/release/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--/app/installSignalHandlers=0', '--ext-folder', '/home/ronim/isaacsim/_build/linux-x86_64/release/exts', '--ext-folder', '/home/ronim/isaacsim/_build/linux-x86_64/release/apps', '--/renderer/activeGpu=0', '--/physics/cudaDevice=0', '--/plugins/carb.tasking.plugin/threadCount=16', '--/plugins/omni.tbb.globalcontrol/maxThreadCount=16', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['--f=/run/user/1000/jupyter/runtime/kernel-v3f69161ef4423996bfa0b48606baa25a4448d08a4.json']
# [Warning] [simulation_app.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/logs/Kit/Isaac-Sim Python/5.0/kit_20250716_160651.log
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/13f3fc3f-a58f-4786-0ba71ba5-efacd9da.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/3e55e1f3-795b-4933-909649a3-37ff9e4a.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/d51f64c0-3713-4b51-2ed85bbd-8cf278ea.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/1b96b9f0-1445-4f00-9e97b18a-d8b18c8c.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/8e7f7f34-5201-476a-f88ee3af-9736fd3f.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/bf03063c-fec5-4fcd-7a2925aa-90c4599a.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/ffff1095-b66e-46db-ef54098f-0b6e2bb6.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/ea2cd8e9-8470-4365-ff564b99-0523f5a9.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0/cb4675b3-8aee-4f7e-758702ab-f7b0c396.dmp'
# 2025-07-16T13:06:51Z s] [Warning] [carb.crashreporter-breakpad.plugin] [previous crash] preventing upload of minidump due to user opt-out: '/home/ronim/.cache/packman/chk/kit-kernel/107.3.0+feature.199947.b0a86421.gl.manylinux_2_35_x86_64.release/data/Kit/Isaac-Sim Python/5.0
] [ext: omni.gpu_foundation-0.0.0] startup
# [0.437s] [ext: carb.windowing.plugins-1.0.0] startup
# 2025-07-16T13:06:52Z s] [Warning] [carb.windowing-glfw.gamepad] Joystick with unknown remapping detected (will be ignored):  Microsoft Microsoft® 2.4GHz Transceiver v8.0 System Control [030000005e040000b207000011010000]
# [0.445s] [ext: omni.kit.renderer.init-0.0.0] startup
# 2025-07-16T13:06:52Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (ARL)
# 2025-07-16T13:06:52Z s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (ARL)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 570.169       | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 5070 Laptop.. | Yes: 0 |     | 8151    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2d58      | ef246e4b.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | Intel(R) Graphics (ARL)          |        |     | 15758   MB | 8086      | 0          |
# |     |                                  |        |     |            | 7d51      | 8680517d.. |
# |     |                                  |        |     |            | 0         |            |
# |=============================================================================================|
# | OS: 24.04.2 LTS (Noble Numbat) ubuntu, Version: 24.04.2, Kernel: 6.11.0-29-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101011 (1.21.1.11)
# | Processor: Intel(R) Core(TM) Ultra 9 285H
# | Cores: 16 | Logical Cores: 16
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31517 | Free Memory: 16588
# | Total Page/Swap (MB): 8191 | Free Page/Swap: 8191
# |---------------------------------------------------------------------------------------------|
# 2025-07-16T13:06:53Z [1,259ms] [Warning] [gpu.foundation.plugin] CPU performance profile is set to powersave. This profile sets the CPU to the lowest frequency reducing performance.
# 2025-07-16T13:06:53Z [1,267ms] [Warning] [gpu.foundation.plugin] PCIe link width current (8) and maximum (16) for device 0 don't match.
# [1.449s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.451s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.451s] [ext: omni.materialx.libs-1.0.7] startup
# [1.458s] [ext: omni.pip.compute-1.6.2] startup
# [1.459s] [ext: omni.usd.config-1.0.6] startup
# [1.461s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.462s] [ext: omni.usd.libs-1.0.1] startup
# [1.519s] [ext: omni.mdl-56.0.3] startup
# [1.580s] [ext: omni.iray.libs-0.0.0] startup
# [1.586s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [1.588s] [ext: omni.kit.usd.mdl-1.1.4] startup
# [1.667s] [ext: omni.pip.cloud-1.3.6] startup
# [1.669s] [ext: omni.isaac.core_archive-2.6.1] startup
# [1.669s] [ext: omni.kit.telemetry-0.5.2] startup
# [1.694s] [ext: omni.kit.loop-isaac-1.3.2] startup
# [1.696s] [ext: omni.kit.test-2.0.1] startup
# [1.724s] [ext: omni.isaac.ml_archive-3.0.2] startup
# [1.724s] [ext: omni.appwindow-1.1.10] startup
# [1.726s] [ext: omni.kit.renderer.core-1.1.0] startup
# [1.923s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.926s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [2.168s] [ext: omni.ui-2.26.17] startup
# [2.188s] [ext: omni.kit.mainwindow-1.0.3] startup
# [2.192s] [ext: carb.audio-0.1.0] startup
# [2.198s] [ext: omni.uiaudio-1.0.0] startup
# [2.199s] [ext: omni.kit.uiapp-0.0.0] startup
# [2.199s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [2.203s] [ext: omni.usd.schema.anim-0.0.0] startup
# [2.219s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [2.223s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [2.225s] [ext: omni.anim.graph.schema-107.3.0] startup
# [2.230s] [ext: omni.usd.schema.audio-0.0.0] startup
# [2.232s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [2.234s] [ext: omni.usd_resolver-1.0.0] startup
# [2.237s] [ext: usdrt.scenegraph-7.6.1] startup
# [2.267s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.269s] [ext: omni.timeline-1.0.14] startup
# [2.271s] [ext: omni.usd.core-1.5.3] startup
# [2.273s] [ext: omni.resourcemonitor-107.0.1] startup
# [2.274s] [ext: omni.activity.core-1.0.3] startup
# [2.275s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [2.277s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [2.282s] [ext: omni.graph.exec-0.9.6] startup
# [2.282s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.285s] [ext: omni.kit.exec.core-0.13.4] startup
# [2.287s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [2.288s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.289s] [ext: omni.kit.commands-1.4.10] startup
# [2.292s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [2.295s] [ext: omni.usd-1.13.9] startup
# 2025-07-16T13:06:54Z [2,309ms] [Warning] [omni.usd.audio] failed to subscribe to stage events
# [2.335s] [ext: omni.inspect-1.0.2] startup
# [2.336s] [ext: omni.kit.notification_manager-1.0.10] startup
# [2.338s] [ext: omni.graph.core-2.184.2] startup
# [2.340s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [2.341s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.344s] [ext: omni.usd.schema.isaac-3.0.5] startup
# [2.344s] [ext: isaacsim.robot.schema-3.5.1] startup
# [2.351s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [2.352s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [2.353s] [ext: omni.anim.navigation.schema-107.3.0] startup
# [2.355s] [ext: omni.usd.schema.physx-107.3.10] startup
# [2.382s] [ext: omni.usd.schema.flow-107.1.1] startup
# [2.382s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [2.383s] [ext: omni.kit.asset_converter-4.1.1] startup
# [2.392s] [ext: omni.convexdecomposition-107.3.10] startup
# [2.395s] [ext: omni.graph.tools-1.79.2] startup
# [2.414s] [ext: omni.physx.foundation-107.3.10] startup
# [2.416s] [ext: omni.kvdb-107.3.10] startup
# [2.417s] [ext: omni.graph.action_core-1.1.7] startup
# [2.418s] [ext: omni.graph-1.141.2] startup
# [2.453s] [ext: omni.usdphysics-107.3.10] startup
# [2.455s] [ext: omni.localcache-107.3.10] startup
# [2.458s] [ext: omni.kit.menu.core-1.1.2] startup
# [2.460s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [2.461s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [2.464s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [2.465s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [2.466s] [ext: omni.kit.clipboard-1.0.5] startup
# [2.467s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [2.469s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [2.471s] [ext: omni.kit.usd.layers-2.2.9] startup
# [2.479s] [ext: omni.kit.menu.utils-2.0.3] startup
# [2.487s] [ext: omni.ui.scene-1.11.4] startup
# [2.491s] [ext: omni.kit.widget.filebrowser-2.12.2] startup
# [2.496s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [2.497s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [2.503s] [ext: omni.kit.window.filepicker-2.13.3] startup
# [2.512s] [ext: omni.kit.stage_templates-2.0.0] startup
# [2.514s] [ext: omni.graph.action_nodes-1.50.4] startup
# [2.521s] [ext: omni.physx.cooking-107.3.10] startup
# [2.526s] [ext: omni.warp.core-1.7.0] startup
# [2.700s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [2.707s] [ext: omni.physx-107.3.10] startup
# [2.720s] [ext: omni.physics-107.3.10] startup
# [2.728s] [ext: isaacsim.core.experimental.utils-0.1.1] startup
# [2.731s] [ext: omni.graph.action-1.130.0] startup
# [2.733s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [2.736s] [ext: omni.physics.physx-107.3.10] startup
# [2.739s] [ext: omni.physics.stageupdate-107.3.10] startup
# [2.766s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.770s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [2.784s] [ext: isaacsim.test.docstring-1.0.8] startup
# [2.788s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# 2025-07-16T13:06:54Z [2,777ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [2.794s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [2.796s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [2.802s] [ext: omni.physics.tensors-107.3.10] startup
# [2.812s] [ext: omni.index.libs-380600.5717.0] startup
# [2.813s] [ext: omni.volume-0.5.2] startup
# [2.818s] [ext: omni.ujitso.client-0.0.0] startup
# [2.819s] [ext: omni.index-1.0.1] startup
# [2.820s] [ext: omni.usd.metrics.assembler.physics-107.3.10] startup
# [2.824s] [ext: omni.hydra.rtx-1.0.0] startup
# 2025-07-16T13:06:54Z [2,836ms] [Warning] [omni.log] Source: omni.hydra was already registered.
# [2.867s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [2.870s] [ext: omni.kit.viewport.legacy_gizmos-1.0.18] startup
# [2.873s] [ext: omni.kit.raycast.query-1.1.0] startup
# [2.879s] [ext: omni.kit.context_menu-1.8.6] startup
# [2.882s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [2.886s] [ext: omni.kit.hydra_texture-1.4.4] startup
# [2.889s] [ext: omni.kit.window.file_importer-1.1.17] startup
# [2.893s] [ext: isaacsim.core.version-2.0.6] startup
# [2.893s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [2.896s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [2.899s] [ext: omni.kit.material.library-2.0.7] startup
# [2.905s] [ext: isaacsim.storage.native-1.2.4] startup
# [2.909s] [ext: omni.kit.viewport.window-107.0.12] startup
# [2.928s] [ext: omni.physx.tensors-107.3.10] startup
# [2.932s] [ext: isaacsim.core.utils-3.4.1] startup
# [2.935s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [2.938s] [ext: omni.kit.menu.create-2.0.1] startup
# [2.940s] [ext: isaacsim.core.simulation_manager-1.2.2] startup
# [4.207s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [4.217s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [4.221s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [4.227s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [4.231s] [ext: omni.kit.usd.collect-2.4.5] startup
# [4.236s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [4.240s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [4.243s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [4.246s] [ext: omni.kit.window.file-2.0.5] startup
# [4.252s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [4.256s] [ext: omni.kit.widget.filter-1.1.4] startup
# [4.259s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [4.261s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [4.263s] [ext: omni.kit.widget.stage-3.1.4] startup
# [4.276s] [ext: omni.kit.window.property-1.12.1] startup
# [4.279s] [ext: omni.kit.window.content_browser-3.1.1] startup
# [4.290s] [ext: omni.kit.window.stage-2.6.1] startup
# [4.295s] [ext: omni.kit.property.usd-4.5.11] startup
# [4.307s] [ext: omni.ui_query-1.1.8] startup
# [4.309s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [4.310s] [ext: omni.kit.ui_test-1.3.6] startup
# [4.312s] [ext: omni.kit.tool.collect-2.2.18] startup
# [4.315s] [ext: omni.kit.scripting-107.3.0] startup
# [4.320s] [ext: isaacsim.core.experimental.prims-0.5.2] startup
# [4.340s] [ext: omni.kit.widget.zoombar-1.0.6] startup
# [4.346s] [ext: omni.kit.window.extensions-1.4.26] startup
# [4.358s] [ext: isaacsim.replicator.behavior-1.1.9] startup
# [4.361s] [ext: isaacsim.core.experimental.objects-0.2.1] startup
# [4.368s] [ext: omni.kit.browser.core-2.3.13] startup
# [4.377s] [ext: omni.kit.usdz_export-1.0.8] startup
# [4.382s] [ext: omni.kit.menu.stage-1.2.7] startup
# [4.385s] [ext: omni.kit.browser.folder.core-1.10.9] startup
# [4.392s] [ext: omni.kit.tool.asset_importer-4.3.0] startup
# [4.400s] [ext: isaacsim.gui.components-1.1.6] startup
# [4.406s] [ext: isaacsim.examples.browser-0.1.12] startup
# [4.416s] [ext: isaacsim.asset.importer.urdf-2.4.13] startup
# [4.527s] [ext: isaacsim.simulation_app-2.9.0] startup
# [4.530s] [ext: omni.graph.ui_nodes-1.50.5] startup
# [4.541s] [ext: omni.isaac.kit-2.0.6] startup
# 2025-07-16T13:06:56Z [4,528ms] [Warning] [omni.isaac.kit] omni.isaac.kit has been deprecated in favor of isaacsim.simulation_app. Please update your code accordingly.
# [4.545s] [ext: omni.kit.widget.graph-2.0.0] startup
# [4.559s] [ext: omni.graph.image.core-0.6.1] startup
# [4.561s] [ext: omni.kit.widget.settings-1.2.3] startup
# [4.564s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [4.567s] [ext: omni.graph.image.nodes-1.3.1] startup
# [4.570s] [ext: omni.kit.window.preferences-1.8.0] startup
# [4.585s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [4.591s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [4.597s] [ext: omni.graph.nodes-1.170.10] startup
# [4.613s] [ext: omni.kit.viewport.menubar.core-107.1.5] startup
# [4.648s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [4.654s] [ext: omni.videoencoding-0.1.2] startup
# [4.658s] [ext: isaacsim.core.prims-0.4.0] startup
# [4.675s] [ext: omni.warp-1.7.0] startup
# [4.682s] [ext: omni.syntheticdata-0.6.13] startup
# [4.714s] [ext: omni.kit.window.material_graph-1.8.23] startup
# [4.815s] [ext: omni.graph.scriptnode-1.50.0] startup
# [4.824s] [ext: isaacsim.core.api-4.6.1] startup
# [4.880s] [ext: omni.replicator.core-1.12.10] startup
# 2025-07-16T13:06:56Z [4,875ms] [Warning] [pxr.Semantics] pxr.Semantics is deprecated - please use Semantics instead
# Warp 1.7.0 initialized:
#    CUDA Toolkit 12.8, Driver 12.8
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 5070 Laptop GPU" (8 GiB, sm_120, mempool enabled)
#    Kernel cache:
#      /home/ronim/.cache/warp/1.7.0
# 2025-07-16T13:06:56Z [5,044ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [5.066s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [5.083s] [ext: isaacsim.robot.surface_gripper-3.2.2] startup
# [5.092s] [ext: isaacsim.core.nodes-3.2.6] startup
# [5.109s] [ext: isaacsim.robot_motion.motion_generation-8.0.21] startup
# [5.157s] [ext: isaacsim.robot.manipulators-3.3.2] startup
# [5.175s] [ext: omni.isaac.core_nodes-2.0.6] startup
# 2025-07-16T13:06:57Z [5,169ms] [Warning] [omni.isaac.core_nodes] omni.isaac.core_nodes has been deprecated in favor of isaacsim.core.nodes. Please update your code accordingly.
# [5.190s] [ext: isaacsim.robot.manipulators.examples-1.0.13] startup
# [5.203s] [ext: omni.kit.property.audio-1.0.16] startup
# [5.212s] [ext: isaacsim.cortex.framework-1.0.9] startup
# [5.216s] [ext: omni.kit.property.camera-1.0.10] startup
# [5.241s] [ext: omni.hydra.scene_api-0.1.2] startup
# [5.261s] [ext: omni.kit.property.geometry-2.0.4] startup
# [5.292s] [ext: omni.kit.property.light-1.0.12] startup
# [5.322s] [ext: isaacsim.cortex.behaviors-2.0.9] startup
# [5.326s] [ext: omni.kit.property.material-1.11.9] startup
# [5.351s] [ext: omni.kit.property.transform-1.5.12] startup
# ...
# 2025-07-16T13:06:57Z [6,103ms] [Warning] [omni.isaac.motion_generation.trajectory] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025
Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,370ms] [Warning] [omni.isaac.sensor.scripts.samples.lightbeam_sensor] omni.isaac.sensor.scripts.samples.lightbeam_sensor has been deprecated in favor of isaacsim.sensors.physx.scripts.samples.lightbeam_sensor. Please update your code accordingly.
# [6.387s] [ext: omni.isaac.cloner-1.0.7] startup
# 2025-07-16T13:06:58Z [6,373ms] [Warning] [omni.isaac.cloner] omni.isaac.cloner has been deprecated in favor of isaacsim.core.cloner. Please update your code accordingly.
# [6.390s] [ext: omni.kit.viewport.menubar.render-107.0.9] startup
# [6.395s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [6.415s] [ext: isaacsim.replicator.writers-1.0.12] startup
# [6.428s] [ext: omni.kit.window.console-1.1.4] startup
# [6.438s] [ext: omni.kit.window.status_bar-0.1.8] startup
# [6.444s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [6.450s] [ext: isaacsim.replicator.domain_randomization-1.0.13] startup
# [6.456s] [ext: isaacsim.replicator.examples-1.1.25] startup
# [6.461s] [ext: omni.ocio-0.1.1] startup
# [6.467s] [ext: omni.rtx.window.settings-0.6.19] startup
# [6.493s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [6.504s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [6.512s] [ext: omni.replicator.isaac-2.0.8] startup
# 2025-07-16T13:06:58Z [6,497ms] [Warning] [omni.replicator.isaac] omni.replicator.isaac has been deprecated in favor of isaacsim.replicator.domain_randomization, isaacsim.replicator.examples, isaacsim.replicator.writers. Please update your code accordingly.
# [6.515s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [6.555s] [ext: omni.rtx.settings.core-0.6.5] startup
# [6.564s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [6.590s] [ext: omni.isaac.surface_gripper-2.0.6] startup
# 2025-07-16T13:06:58Z [6,575ms] [Warning] [omni.isaac.surface_gripper] omni.isaac.surface_gripper has been deprecated in favor of isaacsim.robot.surface_gripper. Please update your code accordingly.
# [6.592s] [ext: semantics.schema.editor-2.0.1] startup
# [6.602s] [ext: omni.kit.ui.actions-1.0.5] startup
# [6.604s] [ext: semantics.schema.property-2.0.1] startup
# [6.606s] [ext: omni.isaac.universal_robots-1.0.6] startup
# 2025-07-16T13:06:58Z [6,591ms] [Warning] [omni.isaac.universal_robots] omni.isaac.universal_robots has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,591ms] [Warning] [omni.isaac.universal_robots.kinematics_solver] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,592ms] [Warning] [omni.isaac.universal_robots.ur10] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# [6.609s] [ext: omni.isaac.core-4.0.7] startup
# 2025-07-16T13:06:58Z [6,594ms] [Warning] [omni.isaac.core.physics_context.physics_context] omni.isaac.core.physics_context.physics_context has been deprecated in favor of isaacsim.core.api.physics_context.physics_context. Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,595ms] [Warning] [omni.isaac.core.simulation_context.simulation_context] omni.isaac.core.simulation_context.simulation_context has been deprecated in favor of isaacsim.core.api.simulation_context.simulation_context. Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,595ms] [Warning] [omni.isaac.core.world.world] omni.isaac.core.world.world has been deprecated in favor of isaacsim.core.api.world.world. Please update your code accordingly.
# 2025-07-16T13:06:58Z [6,595ms] [Warning] [omni.isaac.core] omni.isaac.core has been deprecated in favor of isaacsim.core.api. Please update your code accordingly.
# [6.612s] [ext: isaacsim.gui.sensors.icon-2.0.0] startup
# [6.619s] [ext: isaacsim.core.experimental.materials-0.2.1] startup
# [6.623s] [ext: omni.kit.menu.common-2.0.0] startup
# [6.628s] [ext: isaacsim.exp.base-5.0.0] startup
# [6.630s] [ext: isaacsim.exp.base.python-5.0.0] startup
# [6.632s] Simulation App Starting
# 2025-07-16T13:06:58Z [7,086ms] [Warning] [omni.fabric.plugin] Warning: attribute viewportHandle not found for bucket id 9
#
# [7.149s] app ready
# 2025-07-16T13:06:59Z [7,349ms] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [carb::dictionary::ISerializer v1.1] (plugin: carb.dictionary.serializer-json.plugin), by client: carb.scenerenderer-rtx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# [12.354s] Simulation App Startup Complete
# 0
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 1
# --------------------------
# 1
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 2
# --------------------------
# 2
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 3
# --------------------------
# 3
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 4
# --------------------------
# 4
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 5
# --------------------------
# 5
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 6
# --------------------------
# 6
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 7
# --------------------------
# 7
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 8
# --------------------------
# 8
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 9
# --------------------------
# 9
# --- LiDAR Sensor Output ---
# First 5 points from the point cloud:
# 10
# --------------------------

# %%
# --- Import Isaac Sim core modules AFTER the simulation app is initialized ---
from isaacsim.core.api import World
from isaacsim.core.api.objects import cuboid
from omni.isaac.sensor import RotatingLidarPhysX
import asyncio
import numpy as np
"""The main asynchronous function to set up and run the simulation."""

# Initialize a World object. The world manages the simulation state, 
# including physics, objects, and the simulation timeline.
world = World(stage_units_in_meters=1.0)

# Add a simple cube to the world for the LiDAR to detect.
# This creates a prim at the specified path and adds a physics collider.
world.scene.add(
    cuboid.VisualCuboid(
        prim_path="/World/MyCube",  # Unique path in the USD stage
        position=np.array([2.0, 0, 0.5]),  # Position in meters [X, Y, Z]
        size=1.0,  # Size of the cube in meters
        color=np.array([0.2, 0.4, 0.8]),  # RGB color
    )
)

# Create and add a rotating LiDAR sensor to the stage.
# This is a high-level wrapper that creates the necessary prims and sets up the sensor.
lidar = world.scene.add(
    RotatingLidarPhysX(
        prim_path="/World/Lidar", # Unique path for the LiDAR prim
        name="MyLidar", # A friendly name for the sensor object
        position=np.array([0, 0, 0.5]), # Position in meters
        # High-level sensor parameters can be set here.
        # For a full list, refer to the RotatingLidarPhysX documentation.
    )
)

# Add a ground plane to the scene. This is a default environment object.
world.scene.add_default_ground_plane()

# Reset the world to ensure all objects are initialized correctly.
# This should be called after adding all objects to the scene.
world.reset()


for i in range(10):
    # This is a simple loop to run the simulation for a few steps.
    # In a real application, you might have more complex logic here.
    # IMPORTANT: A single physics step is required to populate the sensor buffer.
    # The sensor reads data during the physics update, not on creation.
    world.step()
    print(i)

    # After the step, the LiDAR data is available.
    # We can get the current reading from the sensor object.
    point_cloud_data = lidar.get_current_frame()

    # The output is a NumPy array. Let's print some information about it.
    print("--- LiDAR Sensor Output ---")
    # print(f"Point cloud data type: {type(point_cloud_data)}")
    # print(f"Point cloud data shape: {point_cloud_data.shape}")

    # The shape is (N, 3), where N is the number of points detected.
    # Each point is an [X, Y, Z] coordinate in the LiDAR's local frame.
    # if point_cloud_data.shape[0] > 0:
    print("First 5 points from the point cloud:")
    print(point_cloud_data.keys())
    # else:
    #     print("No points were detected in the point cloud.")

    print("--------------------------")

    # Ensure the simulation is stopped and the application is closed.

# %%
lidar.get_current_frame()
# Out:
# {'time': 0, 'physics_step': 0}
