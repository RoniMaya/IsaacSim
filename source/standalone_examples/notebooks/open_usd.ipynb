# %%
from isaacsim import SimulationApp

# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this
simulation_app = SimulationApp()
# Out:
# [Warning] [simulation_app.simulation_app] fast shutdown not supported with jupyter notebooks
# ...

# %%
from omni.isaac.sensor import Camera

camera_path = "/World/camera"
camera = Camera(prim_path=camera_path,
                resolution=(1280, 720),
                frequency=24,
                orientation=UsdGeom.XformCommonAPI.Get(prim_path=camera_path, attributeName="xformOp:orient").Get(),
                position=UsdGeom.XformCommonAPI.Get(prim_path=camera_path, attributeName="xformOp:translate").Get()
               )

camera.initialize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 from omni.isaac.sensor import Camera
#       3 camera_path = "/World/camera"
#       4 camera = Camera(prim_path=camera_path,
#       5                 resolution=(1280, 720),
#       6                 frequency=24,
# ----> 7                 orientation=UsdGeom.XformCommonAPI.Get(prim_path=camera_path, attributeName="xformOp:orient").Get(),
#       8                 position=UsdGeom.XformCommonAPI.Get(prim_path=camera_path, attributeName="xformOp:translate").Get()
#       9                )
#      11 camera.initialize()
#
# NameError: name 'UsdGeom' is not defined
